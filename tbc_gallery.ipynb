# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.thebritishcollege.edu.np/gallery"

headers={
    "User-Agent": "My Web Scraper 1.0 - for educational purposes"
}

response=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(response.text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html data-bs-theme="light" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="cube-desc"/>
# <meta content="FA476E667ABF159650910B41C9420203" name="msvalidate.01"/>
# <meta content="NP" name="distribution"/>
# <meta content="Education" name="classification"/>
# <meta content="7 Days" name="revisit-after"/>
# <meta content="Index, Follow" name="robots"/>
# <meta content="The British College" name="author"/>
# <meta content="Education Courses" name="application-name"/>
# <meta content="EN" http-equiv="content-language"/>
# <meta content="E-Worksuk" name="designer"/>
# <meta content="The British College" name="DC.title"/>
# <meta content="NP-BA" name="geo.region"/>
# <meta content="Kathmandu" name="geo.placename"/>
# <meta content="27.693123;85.319173" name="geo.position"/>
# <meta content="27.693123, 85.319173" name="ICBM"/>
# ...

# %%
#we can use .prettify() to see the HTML in a nicely indented format
print(soup.prettify())

#--Finding Elements--
#Find the first element of a certain tag (eg., the page title)

page_title=soup.find('title')
print(f"Page Title: {page_title.text}")
# Out:
# <!DOCTYPE html>
# <html data-bs-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="" name="cube-desc"/>
#   <meta content="FA476E667ABF159650910B41C9420203" name="msvalidate.01"/>
#   <meta content="NP" name="distribution"/>
#   <meta content="Education" name="classification"/>
#   <meta content="7 Days" name="revisit-after"/>
#   <meta content="Index, Follow" name="robots"/>
#   <meta content="The British College" name="author"/>
#   <meta content="Education Courses" name="application-name"/>
#   <meta content="EN" http-equiv="content-language"/>
#   <meta content="E-Worksuk" name="designer"/>
#   <meta content="The British College" name="DC.title"/>
#   <meta content="NP-BA" name="geo.region"/>
#   <meta content="Kathmandu" name="geo.placename"/>
#   <meta content="27.693123;85.319173" name="geo.position"/>
#   <meta content="27.693123, 85.319173" name="ICBM"/>
# ...

# %%
titles=soup.find_all('div',class_='n-wrap')
print(titles)
# Out:
# [<div class="n-wrap">
# <h4><a href="https://www.thebritishcollege.edu.np/gallery/tbc-career-fest-2024">TBC Career Fest 2024</a></h4>
# <p class="d-line"></p>
# </div>, <div class="n-wrap">
# <h4><a href="https://www.thebritishcollege.edu.np/gallery/tbc-tihar-fest-2024">TBC Tihar Fest 2024</a></h4>
# <p class="d-line"></p>
# </div>, <div class="n-wrap">
# <h4><a href="https://www.thebritishcollege.edu.np/gallery/10th-tbc-graduation-ceremony-2024">10th TBC Graduation Ceremony 2024</a></h4>
# <p class="d-line"></p>
# </div>, <div class="n-wrap">
# <h4><a href="https://www.thebritishcollege.edu.np/gallery/5th-british-cup">5th British Cup</a></h4>
# <p class="d-line"></p>
# </div>, <div class="n-wrap">
# <h4><a href="https://www.thebritishcollege.edu.np/gallery/bmc-freshers-day">BMC Freshers Day</a></h4>
# <p class="d-line"></p>
# </div>, <div class="n-wrap">
# ...

# %%
tbc_gallery=[]
for title in titles:
    tbc_photo_title=title.find('h4')
    photo_title=tbc_photo_title.text
    photo_details={
        'Title':photo_title
    }
    tbc_gallery.append(photo_details)
print(tbc_gallery)
# Out:
# [{'Title': 'TBC Career Fest 2024'}, {'Title': 'TBC Tihar Fest 2024'}, {'Title': '10th TBC Graduation Ceremony 2024'}, {'Title': '5th British Cup'}, {'Title': 'BMC Freshers Day'}, {'Title': 'Cybersecurity Awareness Session'}, {'Title': 'TBC Summer School'}, {'Title': "Topraj Gurung's Tech Talk Session"}, {'Title': 'Understanding Cultural Dynamics in Consumer Behavior'}, {'Title': "Raju Gajurel's Session"}, {'Title': 'BMC investiture Ceremony'}, {'Title': 'TBC Summer Academy | China Week: Summer Course'}]
