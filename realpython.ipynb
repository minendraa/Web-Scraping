# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://realpython.com/"

headers={
    "User-Agent": "My Web Scraper 1.0 - for educational purposes"
}

response=requests.get(url,headers=headers)

# %%
soup=BeautifulSoup(response.text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://files.realpython.com" rel="preconnect"/>
# <title>Python Tutorials – Real Python</title>
# <meta content="Real Python" name="author"/>
# <meta content="Learn Python online: Python tutorials for developers of all skill levels, Python books and courses, Python news, code examples, articles, and more." name="description"/>
# <meta content="" name="keywords"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no, viewport-fit=cover" name="viewport"/>
# <link href="/static/realpython.min.e72e5c2e26a7.css" rel="stylesheet"/>
# <link href="/static/gfonts/font.5ac42994de49.css" rel="stylesheet"/>
# <link as="style" href="/static/glightbox.min.9b438b29cef1.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/><noscript><link href="/static/glightbox.min.9b438b29cef1.css" rel="stylesheet"/></noscript>
# <link href="https://realpython.com/" rel="canonical"/>
# ...

# %%
#we can use .prettify() to see the HTML in a nicely indented format
print(soup.prettify())

#--Finding Elements--
#Find the first element of a certain tag (eg., the page title)

page_title=soup.find('title')
print(f"Page Title: {page_title.text}")
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://files.realpython.com" rel="preconnect"/>
#   <title>
#    Python Tutorials – Real Python
#   </title>
#   <meta content="Real Python" name="author"/>
#   <meta content="Learn Python online: Python tutorials for developers of all skill levels, Python books and courses, Python news, code examples, articles, and more." name="description"/>
#   <meta content="" name="keywords"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no, viewport-fit=cover" name="viewport"/>
#   <link href="/static/realpython.min.e72e5c2e26a7.css" rel="stylesheet"/>
#   <link href="/static/gfonts/font.5ac42994de49.css" rel="stylesheet"/>
#   <link as="style" href="/static/glightbox.min.9b438b29cef1.css" onload="this.onload=null;this.rel='stylesheet'" rel="preload"/>
#   <noscript>
#    <link href="/static/glightbox.min.9b438b29cef1.css" rel="stylesheet"/>
#   </noscript>
# ...

# %%
titles=soup.find_all('h2',class_='card-title')
print(titles)
# Out:
# [<h2 class="card-title h2 my-0 py-0">Python enumerate(): Simplify Loops That Need Counters</h2>, <h2 class="card-title h4 my-0 py-0">Python Project: Build a Word Count Command-Line App</h2>, <h2 class="card-title h4 my-0 py-0">Exploring Python's list Data Type With Examples</h2>, <h2 class="card-title h4 my-0 py-0">Write Pythonic and Clean Code With namedtuple</h2>, <h2 class="card-title h4 my-0 py-0">Defining Your Own Python Function</h2>, <h2 class="card-title h4 my-0 py-0">Python Continuous Integration and Deployment Using GitHub Actions</h2>, <h2 class="card-title h4 my-0 py-0">Python Hits the Big Screen and Other Python News for June 2025</h2>, <h2 class="card-title h4 my-0 py-0">How to Find an Absolute Value in Python</h2>, <h2 class="card-title h4 my-0 py-0">Execute Your Python Scripts With a Shebang</h2>, <h2 class="card-title h4 my-0 py-0">How Can You Structure Your Python Script?</h2>, <h2 class="card-title h4 my-0 py-0">Control Flow Structures in Python</h2>, <h2 class="ca
# ...

# %%
title_list=[]
for title in titles:
    title_name=title.text
    title_details={
        'title':title_name
    }
    title_list.append(title_details)
print(title_list)
# Out:
# [{'title': 'Python enumerate(): Simplify Loops That Need Counters'}, {'title': 'Python Project: Build a Word Count Command-Line App'}, {'title': "Exploring Python's list Data Type With Examples"}, {'title': 'Write Pythonic and Clean Code With namedtuple'}, {'title': 'Defining Your Own Python Function'}, {'title': 'Python Continuous Integration and Deployment Using GitHub Actions'}, {'title': 'Python Hits the Big Screen and Other Python News for June 2025'}, {'title': 'How to Find an Absolute Value in Python'}, {'title': 'Execute Your Python Scripts With a Shebang'}, {'title': 'How Can You Structure Your Python Script?'}, {'title': 'Control Flow Structures in Python'}, {'title': 'The LEGB Rule & Understanding Python Scope'}, {'title': 'marimo: A Reactive, Reproducible Notebook'}, {'title': 'Nested Loops in Python'}, {'title': 'First Steps With LangChain'}, {'title': 'How to Group Data Using Polars .group_by()'}, {'title': 'How to Get the Most Out of PyCon US'}, {'title': 'Working With
# ...

# %%
datas=soup.find_all('div',class_='card-body')
print(datas)
# Out:
# [<div class="card-body m-0 p-0 pt-3">
# <a href="/python-enumerate/">
# <h2 class="card-title h2 my-0 py-0">Python enumerate(): Simplify Loops That Need Counters</h2>
# </a>
# <p class="my-1">Learn how to simplify your loops with Python’s enumerate(). This tutorial shows you how to pair items with their index cleanly and effectively using real-world examples.</p>
# <p class="card-text">
# <small class="text-muted">
# <span class="mr-2">Jun 23, 2025</span>
# <span aria-hidden="true" class="icon baseline ml-2"><svg aria-hidden="true"><use href="/static/icons.437b3be14035.svg#@category"></use></svg></span>
# <a class="badge badge-light text-muted" data-previewable="" href="/tutorials/basics/">basics</a>
# <a class="badge badge-light text-muted" data-previewable="" href="/tutorials/best-practices/">best-practices</a>
# </small>
# </p>
# </div>, <div class="card-body text-center highlight-hover-dark rounded">
# ...

# %%
for data in datas:
    print(data)
    title_name=data.find('h2',class_='card_title')

    print(title_name)
    print("---"*10)
# Out:
# <div class="card-body m-0 p-0 pt-3">
# <a href="/python-enumerate/">
# <h2 class="card-title h2 my-0 py-0">Python enumerate(): Simplify Loops That Need Counters</h2>
# </a>
# <p class="my-1">Learn how to simplify your loops with Python’s enumerate(). This tutorial shows you how to pair items with their index cleanly and effectively using real-world examples.</p>
# <p class="card-text">
# <small class="text-muted">
# <span class="mr-2">Jun 23, 2025</span>
# <span aria-hidden="true" class="icon baseline ml-2"><svg aria-hidden="true"><use href="/static/icons.437b3be14035.svg#@category"></use></svg></span>
# <a class="badge badge-light text-muted" data-previewable="" href="/tutorials/basics/">basics</a>
# <a class="badge badge-light text-muted" data-previewable="" href="/tutorials/best-practices/">best-practices</a>
# </small>
# </p>
# </div>
# None
# ------------------------------
# <div class="card-body text-center highlight-hover-dark rounded">
# ...

# %%
for data in datas:
    title
